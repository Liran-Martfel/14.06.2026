# %%
import numpy as np
import pandas as pd

# %%
#1
monday = pd.Series({'Alice' : 8, 'Bob' : 6, 'David' : 7})
monday
# Out:
# Alice    8
# Bob      6
# David    7
# dtype: int64

# %%
#1
tuesday = pd.Series ({'Bob' : 8, 'Carol' : 5, 'David' : 6})
tuesday
# Out:
# Bob      8
# Carol    5
# David    6
# dtype: int64

# %%
#1
wednesday = pd.Series ({'Alice' : 7, 'Carol' : 8, 'David' : 5})
wednesday
# Out:
# Alice    7
# Carol    8
# David    5
# dtype: int64

# %%
#2
weekly_workers = monday.add(tuesday,fill_value = 0).add(wednesday,fill_value = 0)
weekly_workers
# Out:
# Alice    15.0
# Bob      14.0
# Carol    13.0
# David    18.0
# dtype: float64

# %%
#3
total_hours = max(weekly_workers.keys())
total_hours
# Out:
# 'David'

# %%
#Q4 option 1
data = {' Workers Name' : ['Alice','Bob','Carol','David'],'Total Hours' : [15,14,13,18]}
Q = pd.DataFrame (data)
Q
# Out:
#    Workers Name  Total Hours
# 0         Alice           15
# 1           Bob           14
# 2         Carol           13
# 3         David           18

# %%
#Q4 option 2
data = [['Alice',15],['Bob',14],['carol',13],['David',18]]
working_hours = pd.DataFrame (data, columns = ['Name','Hours'])
working_hours
# Out:
#     Name  Hours
# 0  Alice     15
# 1    Bob     14
# 2  carol     13
# 3  David     18
