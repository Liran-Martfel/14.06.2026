# %%
import numpy as np
import pandas as pd

# %%
#create series
pd.Series ([10,100,15,35])
print(type(pd.Series([10,100,15,35])))
# Out:
# <class 'pandas.core.series.Series'>

# %%
years = [1776,1867,1821]
lable_index = ['USA','CANADA','MEXICO']
pd.Series (data = years, index = lable_index)
# Out:
# USA       1776
# CANADA    1867
# MEXICO    1821
# dtype: int64

# %%
#create index ,F-name,L-name,adderes,city,country
#create series that looks like :
#first_name
#last_name
#adderess
#city
#country

#input the values from the user
#create the card from the input

# %%
business_card = ['f_name','l_name','city','country']
name = ['danny','shovevani','rehovot','israel']
pd.Series (name,business_card)
# Out:
# f_name         danny
# l_name     shovevani
# city         rehovot
# country       israel
# dtype: object

# %%
f_name = input ('What is your first name?')
l_name =  input ('What is your last name?')
city_n =  input ('What is your city?')
country_n =  input ('Where do you live?')
business_card_lable = ['first_name','last_name','city','country']
business_card_name = [f_name,l_name,city_n,country_n]
pd.Series(business_card_name,business_card_lable)
# Out:
# What is your first name? Liran
# What is your last name? Martfel
# What is your city? Modiin
# Where do you live? Israel
# first_name      Liran
# last_name     Martfel
# city           Modiin
# country        Israel
# dtype: object

# %%
# Inventory for Tel Aviv Branch
tel_aviv = pd.Series({
    'MacBook Pro': 5, 
    'LG Screen 27': 1, 
    'Logitech Mouse': 12
})

# Inventory for Haifa Branch
haifa = pd.Series({
    'MacBook Pro': 3, 
    'iPad Air': 7, 
    'Logitech Mouse': 8
})

# 1 add another store with random items from store 1 , and store 2 and random stock
# 2 input product type from user 
# 3 print the total items in stock

# %%
#1
modiin = pd.Series ({
    'MacBook Pro': 1, 
    'LG Screen 27': 2,
    'iPad Air': 4
})

#showing all inventory
total_inventory = tel_aviv.add( haifa, fill_value=0).add(modiin, fill_value=0)
total_inventory

#2+3
customers_chooice = input ('enter product name: ')
total_inventory = tel_aviv.add( haifa, fill_value=0).add(modiin, fill_value=0)
print(total_inventory.get(customers_chooice,f'ERROR {customers_chooice} not exist in inventory'))
# Out:
# enter product name:  lanovo
# ERROR lanovo not exist in inventory

# %%
tips_df = pd.read_csv('tips.csv')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...
